# %%
import os
import cv2 as cv
import numpy as np
from random import shuffle

import matplotlib.pyplot as plt
import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import imblearn
from tabulate import tabulate
from keras.optimizers import Adam

print(tf.__version__)
print('okkk')
# Out:
# 2.9.1
# okkk

# %%
train_dir = 'C:\OPPO\Intern5\Train'
test_dir = 'C:\OPPO\Intern5\Test'
val_dir = 'C:\OPPO\Intern5\Val'
batch_size = 32
img_size = (32, 32)

import pathlib
img_train_dir = pathlib.Path(train_dir)
img_test_dir = pathlib.Path(test_dir)
img_val_dir = pathlib.Path(val_dir)
img_train_cnt = len(list(img_train_dir.glob('*/*.png')))
img_test_cnt = len(list(img_test_dir.glob('*/*.png')))
img_val_cnt = len(list(img_val_dir.glob('*/*.png')))
print(img_train_cnt, img_test_cnt, img_val_cnt)

print('Total Images in Train:', img_train_cnt)
print('Total Images in Test:', img_test_cnt)
print('Total Images in Val:', img_val_cnt)
# Out:
# 10115 6810 2310
# Total Images in Train: 10115
# Total Images in Test: 6810
# Total Images in Val: 2310

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  val_dir,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 10115 files belonging to 5 classes.
# Found 2310 files belonging to 5 classes.
# ['No vehicles', 'Others', 'Road narrows on the right', 'Speed limit (30km_h)', 'Speed limit (70km_h)']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(5):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

for image_batch, labels_batch in train_ds.take(1):
  print(image_batch.shape)
  print(labels_batch.shape)
  ##break
# Out:
# (32, 32, 32, 3)
# (32,)

# %%
normalization_layer = layers.Rescaling(1./255)
print("Normalization layer is created")

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
print("This layer is applied to dataset using map function")

image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in [0,1].
print(np.min(first_image), np.max(first_image))

print(class_names)
num_classes = len(class_names)
print(num_classes)
# Out:
# Normalization layer is created
# This layer is applied to dataset using map function
# 0.0 0.6901961
# ['No vehicles', 'Others', 'Road narrows on the right', 'Speed limit (30km_h)', 'Speed limit (70km_h)']
# 5

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_size[0], img_size[1], 3)),
    
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

model.summary()

opt = Adam(learning_rate = 0.0005)
model.compile(optimizer=opt, loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 32, 32, 3)         0
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 16)        448
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)        4640
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 64)          18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 128)         73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 163,749
# Trainable params: 163,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs)

path_to_save = os.path.join(os.getcwd(), 'Models')
model.save(path_to_save)

model = keras.models.load_model(path_to_save)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)
# Out:
# Epoch 1/20
# C:\Users\605246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 317/317 [==============================] - 12s 36ms/step - loss: 0.5885 - accuracy: 0.7710 - val_loss: 0.6448 - val_accuracy: 0.7433
# Epoch 2/20
# 317/317 [==============================] - 10s 32ms/step - loss: 0.0961 - accuracy: 0.9675 - val_loss: 0.2387 - val_accuracy: 0.9411
# Epoch 3/20
# 317/317 [==============================] - 10s 32ms/step - loss: 0.0504 - accuracy: 0.9846 - val_loss: 0.2473 - val_accuracy: 0.9368
# Epoch 4/20
# 317/317 [==============================] - 12s 38ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.1465 - val_accuracy: 0.9571
# Epoch 5/20
# 317/317 [==============================] - 13s 39ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.1941 - val_accuracy: 0.9511
# Epoch 6/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0309 - accuracy: 0.9898 - val_loss: 0.3906 - val_accuracy: 0.9368
# Epoch 7/20
# 317/317 [==============================] - 12s 36ms/step - loss: 0.0259 - accuracy: 0.9924 - val_loss: 0.1951 - val_accuracy: 0.9606
# Epoch 8/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0266 - accuracy: 0.9925 - val_loss: 0.2695 - val_accuracy: 0.9476
# Epoch 9/20
# 317/317 [==============================] - 11s 36ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.2287 - val_accuracy: 0.9641
# Epoch 10/20
# 317/317 [==============================] - 12s 36ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0879 - val_accuracy: 0.9818
# Epoch 11/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0248 - accuracy: 0.9931 - val_loss: 0.0963 - val_accuracy: 0.9766
# Epoch 12/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.1180 - val_accuracy: 0.9740
# Epoch 13/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0205 - accuracy: 0.9945 - val_loss: 0.1098 - val_accuracy: 0.9671
# Epoch 14/20
# 317/317 [==============================] - 12s 38ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 0.1124 - val_accuracy: 0.9784
# Epoch 15/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.1827 - val_accuracy: 0.9745
# Epoch 16/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.2459 - val_accuracy: 0.9515
# Epoch 17/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0183 - accuracy: 0.9951 - val_loss: 0.3006 - val_accuracy: 0.9494
# Epoch 18/20
# 317/317 [==============================] - 12s 38ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 0.2032 - val_accuracy: 0.9580
# Epoch 19/20
# 317/317 [==============================] - 12s 38ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.2651 - val_accuracy: 0.9567
# Epoch 20/20
# 317/317 [==============================] - 12s 37ms/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 0.1753 - val_accuracy: 0.9693
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\605246\OPPO\Models\assets
# INFO:tensorflow:Assets written to: C:\Users\605246\OPPO\Models\assets

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir,

  image_size=img_size,
  batch_size=batch_size)

results = model.evaluate(test_ds,batch_size=32)
print(results)
# Out:
# Found 6810 files belonging to 5 classes.
# C:\Users\605246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 213/213 [==============================] - 4s 18ms/step - loss: 0.1299 - accuracy: 0.9780
# [0.1298663169145584, 0.9779735803604126]

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  plt.figure(figsize=(10, 10))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)

  plt.title(title)
  plt.colorbar()

  tick_marks = np.arange(len(classes))

  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  thresh = cm.max() / 2.

  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
target_names = []
class_names = train_ds.class_names
print(class_names)
for key in train_ds.class_names:
    target_names.append(key)

print(target_names)

y= np.concatenate([y for x,y in test_ds],axis=0)
Y_pred = model.predict(test_ds)
y_pred = np.argmax(Y_pred, axis=1)

y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for image_batch, label_batch in test_ds:  # use dataset.unbatch() with repeat
  # append true labels
  y_true.append(label_batch)
  # compute predictions
  preds = model.predict(image_batch)
  # append predicted labels
  y_pred.append(np.argmax(preds, axis=- 1))

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis=0)
predicted_labels = tf.concat([item for item in y_pred], axis=0)

cm = tf.math.confusion_matrix(
  correct_labels,
  predicted_labels,
  num_classes=5,
  weights=None,
  dtype=tf.dtypes.int32, )
print('Confusion matrix:')
print(cm)
matrix = classification_report(correct_labels, predicted_labels, target_names=class_names)
print('Classification report : \n', matrix)
# Out:
# ['No vehicles', 'Others', 'Road narrows on the right', 'Speed limit (30km_h)', 'Speed limit (70km_h)']
# ['No vehicles', 'Others', 'Road narrows on the right', 'Speed limit (30km_h)', 'Speed limit (70km_h)']
# 213/213 [==============================] - 5s 21ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 100ms/step
# Confusion matrix:
# tf.Tensor(
# [[ 205    0    0    0    5]
#  [  28 5011   20   13   58]
#  [   0    3   87    0    0]
#  [   1    8    0  709    2]
#  [   0   12    0    0  648]], shape=(5, 5), dtype=int32)
# Classification report :
#                             precision    recall  f1-score   support
#
#               No vehicles       0.88      0.98      0.92       210
#                    Others       1.00      0.98      0.99      5130
# Road narrows on the right       0.81      0.97      0.88        90
#      Speed limit (30km_h)       0.98      0.98      0.98       720
#      Speed limit (70km_h)       0.91      0.98      0.94       660
#
#                  accuracy                           0.98      6810
#                 macro avg       0.92      0.98      0.94      6810
#              weighted avg       0.98      0.98      0.98      6810
